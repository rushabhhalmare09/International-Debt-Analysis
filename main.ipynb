# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import datetime as datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### *Load Dataset*

# %%
#
file= pd.read_csv("../IDS_CSV/IDS_ALLCountries_Data.csv")

# %%
file.head(5)
# Out:
#   Country Name Country Code Counterpart-Area Name Counterpart-Area Code  \
# 0  Afghanistan          AFG                 World                   WLD
# 1  Afghanistan          AFG                 World                   WLD
# 2  Afghanistan          AFG                 World                   WLD
# 3  Afghanistan          AFG                 World                   WLD
# 4  Afghanistan          AFG                 World                   WLD
#
#                                          Series Name  Series Code  1970  1971  \
# 0  Average grace period on new external debt comm...  DT.GPA.DPPG   NaN   NaN
# 1  Average grace period on new external debt comm...  DT.GPA.OFFT   NaN   NaN
# 2  Average grace period on new external debt comm...  DT.GPA.PRVT   NaN   NaN
# 3  Average grant element on new external debt com...  DT.GRE.DPPG   NaN   NaN
# 4  Average grant element on new external debt com...  DT.GRE.OFFT   NaN   NaN
#
# ...

# %%
file['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Azerbaijan', 'Bangladesh', 'Belarus', 'Belize',
#        'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde',
#        'Cambodia', 'Cameroon', 'Central African Republic', 'Chad',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Djibouti', 'Dominica',
#        'Dominican Republic',
#        'East Asia & Pacific (excluding high income)', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Eritrea', 'Eswatini',
#        'Ethiopia', 'Europe & Central Asia (excluding high income)',
#        'Fiji', 'Gabon', 'Gambia, The', 'Georgia', 'Ghana', 'Grenada',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'IDA only', 'India', 'Indonesia', 'Iran, Islamic Rep.',
# ...

# %%
#Saving file in a variable and converting to ISO-8859-1 format
csv6= "../IDS_CSV/IDS_SeriesMetaData.csv"

file1 = pd.read_csv(csv6, encoding='ISO-8859-1')

# %%
file1.head(5)
# Out:
#           Code License Type  \
# 0  DT.GPA.DPPG          NaN
# 1  DT.GPA.OFFT          NaN
# 2  DT.GPA.PRVT          NaN
# 3  DT.GRE.DPPG          NaN
# 4  DT.GRE.OFFT          NaN
#
#                                       Indicator Name  \
# 0  Average grace period on new external debt comm...
# 1  Average grace period on new external debt comm...
# 2  Average grace period on new external debt comm...
# 3  Average grant element on new external debt com...
# 4  Average grant element on new external debt com...
#
#                                     Short definition  \
# 0  Grace period is the period from the date of si...
# 1  Grace period is the period from the date of si...
# 2  Grace period is the period from the date of si...
# 3  The grant element of a loan is the grant equiv...
# 4  The grant element of a loan is the grant equiv...
#
#                                      Long definition  \
# 0  Grace period is the period from the date of si...
# ...

# %% [markdown]
# #### *Joining two Dataset*

# %%
# fileSource.merge(fileDestination, left_on='lkey', right_on='rkey')  -- merging data into source

merge_file = file.merge(file1, left_on='Series Code', right_on='Code' )

# %% [markdown]
# #### *Creating CSV File*

# %%
merge_file.to_csv("JoinedDataSet.csv")

# %%
merge_file.head(5)
# Out:
#   Country Name Country Code Counterpart-Area Name Counterpart-Area Code  \
# 0  Afghanistan          AFG                 World                   WLD
# 1      Albania          ALB                 World                   WLD
# 2      Algeria          DZA                 World                   WLD
# 3       Angola          AGO                 World                   WLD
# 4    Argentina          ARG                 World                   WLD
#
#                                          Series Name  Series Code    1970  \
# 0  Average grace period on new external debt comm...  DT.GPA.DPPG     NaN
# 1  Average grace period on new external debt comm...  DT.GPA.DPPG     NaN
# 2  Average grace period on new external debt comm...  DT.GPA.DPPG  3.5975
# 3  Average grace period on new external debt comm...  DT.GPA.DPPG     NaN
# 4  Average grace period on new external debt comm...  DT.GPA.DPPG  2.9281
#
#      1971    1972    1973  ...  License Type  \
# ...

# %% [markdown]
# #### **Creating a new Column and adding all the debt yearwise into single column Debt**

# %%
# df['Sum']=df.iloc[:,1:3].sum(axis=1) print(df)

merge_file['debt']=merge_file.iloc[:,6:64].sum(axis=1)

# %%
merge_file.describe()
# Out:
#                1970          1971          1972          1973          1974  \
# count  3.499300e+04  3.584300e+04  3.657600e+04  3.736000e+04  3.791300e+04
# mean   2.418032e+08  2.615074e+08  2.960808e+08  3.708542e+08  4.697524e+08
# std    5.287998e+09  5.676280e+09  6.335208e+09  7.936191e+09  9.931066e+09
# min   -1.684299e+09 -2.095143e+09 -4.723625e+08 -2.899000e+08 -3.117914e+09
# 25%    7.220000e-02  2.380550e+00  6.050350e+00  7.668257e+00  1.392980e+01
# 50%    1.654475e+06  1.826000e+06  2.359205e+06  2.848000e+06  3.481873e+06
# 75%    2.174353e+07  2.423075e+07  3.030630e+07  3.611921e+07  4.597607e+07
# max    5.843440e+11  6.310940e+11  7.092430e+11  8.970180e+11  1.137400e+12
#
#                1975          1976          1977          1978          1979  \
# count  3.868700e+04  3.916500e+04  4.005600e+04  4.071400e+04  4.099100e+04
# mean   5.624011e+08  6.298892e+08  7.691486e+08  9.111953e+08  1.087913e+09
# ...

# %%
merge_file.columns
# Out:
# Index(['Country Name', 'Country Code', 'Counterpart-Area Name',
#        'Counterpart-Area Code', 'Series Name', 'Series Code', '1970', '1971',
#        '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025',
#        '2026', '2027', '2028', 'Code', 'License Type', 'Indicator Name',
#        'Short definition', 'Long definition', 'Source', 'Topic', 'Dataset',
#        'Periodicity', 'Aggregation method', 'General comments', 'debt'],
#       dtype='object')

# %%
merge_file.dtypes
# Out:
# Country Name              object
# Country Code              object
# Counterpart-Area Name     object
# Counterpart-Area Code     object
# Series Name               object
#                           ...
# Dataset                   object
# Periodicity               object
# Aggregation method        object
# General comments          object
# debt                     float64
# Length: 77, dtype: object

# %%
merge_file.isnull()
# Out:
#        Country Name  Country Code  Counterpart-Area Name  \
# 0             False         False                  False
# 1             False         False                  False
# 2             False         False                  False
# 3             False         False                  False
# 4             False         False                  False
# ...             ...           ...                    ...
# 77379         False         False                  False
# 77380         False         False                  False
# 77381         False         False                  False
# 77382         False         False                  False
# 77383         False         False                  False
#
#        Counterpart-Area Code  Series Name  Series Code   1970   1971   1972  \
# 0                      False        False        False   True   True   True
# 1                      False        False        False   True   True   True
# ...

# %% [markdown]
# #### **After Adding Debt Column**

# %%
afterDebt_col = merge_file.to_csv("AddingDebtColumn_JoinedDataSet.csv")

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# #### **Check for null values**

# %%
merge_file['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Azerbaijan', 'Bangladesh', 'Belarus', 'Belize',
#        'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde',
#        'Cambodia', 'Cameroon', 'Central African Republic', 'Chad',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Djibouti', 'Dominica',
#        'Dominican Republic',
#        'East Asia & Pacific (excluding high income)', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Eritrea', 'Eswatini',
#        'Ethiopia', 'Europe & Central Asia (excluding high income)',
#        'Fiji', 'Gabon', 'Gambia, The', 'Georgia', 'Ghana', 'Grenada',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'IDA only', 'India', 'Indonesia', 'Iran, Islamic Rep.',
# ...

# %%
countrywise = merge_file.groupby([ 'Country Name' , 'Series Code', 'debt'])['debt'].count()

countrywise
# Out:
# Country Name  Series Code        debt
# Afghanistan   BM.GSR.TOTL.CD     96370208795.000     1
#               BN.CAB.XOKA.CD     -37545157209.200    1
#               BX.GRT.EXTA.CD.DT  59299370000.000     1
#               BX.GRT.TECH.CD.DT  9027510000.000      1
#               BX.GSR.TOTL.CD     26392909373.000     1
#                                                     ..
# Zimbabwe      DT.UND.PRVT.CD     4656223137.700      1
#               FI.RES.TOTL.CD     11486436779.940     1
#               FI.RES.TOTL.DT.ZS  579.702             1
#               FI.RES.TOTL.MO     29.061              1
#               NY.GNP.MKTP.CD     416213755386.000    1
# Name: debt, Length: 77384, dtype: int64

# %%
merge_file.head()
# Out:
#   Country Name Country Code Counterpart-Area Name Counterpart-Area Code  \
# 0  Afghanistan          AFG                 World                   WLD
# 1      Albania          ALB                 World                   WLD
# 2      Algeria          DZA                 World                   WLD
# 3       Angola          AGO                 World                   WLD
# 4    Argentina          ARG                 World                   WLD
#
#                                          Series Name  Series Code  1970  1971  \
# 0  Average grace period on new external debt comm...  DT.GPA.DPPG   NaN   NaN
# 1  Average grace period on new external debt comm...  DT.GPA.DPPG   NaN   NaN
# 2  Average grace period on new external debt comm...  DT.GPA.DPPG 3.598 5.658
# 3  Average grace period on new external debt comm...  DT.GPA.DPPG   NaN   NaN
# 4  Average grace period on new external debt comm...  DT.GPA.DPPG 2.928 2.596
#
# ...

# %%
csv_file = merge_file[["Country Name", "Country Code", "Indicator Name", "Series Code", "debt"]]
csv_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77384 entries, 0 to 77383
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    77384 non-null  object
#  1   Country Code    77384 non-null  object
#  2   Indicator Name  76432 non-null  object
#  3   Series Code     77384 non-null  object
#  4   debt            77384 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 3.5+ MB

# %%
csv_file.to_csv("Final.csv")

# %%
cleaned_csv_file = pd.read_csv("../IDS_CSV/FinalCleanedCSV.csv")

# %%
csv_file.head(10)
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1      Albania          ALB
# 2      Algeria          DZA
# 3       Angola          AGO
# 4    Argentina          ARG
# 5      Armenia          ARM
# 6   Azerbaijan          AZE
# 7   Bangladesh          BGD
# 8      Belarus          BLR
# 9       Belize          BLZ
#
#                                       Indicator Name  Series Code    debt
# 0  Average grace period on new external debt comm...  DT.GPA.DPPG 103.697
# 1  Average grace period on new external debt comm...  DT.GPA.DPPG 217.086
# 2  Average grace period on new external debt comm...  DT.GPA.DPPG 164.481
# 3  Average grace period on new external debt comm...  DT.GPA.DPPG  70.853
# 4  Average grace period on new external debt comm...  DT.GPA.DPPG 272.843
# 5  Average grace period on new external debt comm...  DT.GPA.DPPG 224.736
# 6  Average grace period on new external debt comm...  DT.GPA.DPPG 151.588
# ...

# %%
cleaned_csv_file.head(10)
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1      Albania          ALB
# 2      Algeria          DZA
# 3       Angola          AGO
# 4    Argentina          ARG
# 5      Armenia          ARM
# 6   Azerbaijan          AZE
# 7   Bangladesh          BGD
# 8      Belarus          BLR
# 9       Belize          BLZ
#
#                                       Indicator Name  Series Code    debt
# 0  Average grace period on new external debt comm...  DT.GPA.DPPG 103.697
# 1  Average grace period on new external debt comm...  DT.GPA.DPPG 217.086
# 2  Average grace period on new external debt comm...  DT.GPA.DPPG 164.481
# 3  Average grace period on new external debt comm...  DT.GPA.DPPG  70.853
# 4  Average grace period on new external debt comm...  DT.GPA.DPPG 272.843
# 5  Average grace period on new external debt comm...  DT.GPA.DPPG 224.736
# 6  Average grace period on new external debt comm...  DT.GPA.DPPG 151.588
# ...

# %% [markdown]
# #### *Finding Number of Distinct Countries*

# %%
distinct_country = cleaned_csv_file['Country Name'].unique()

print("The count of number of Distinct Countries are: -")
len(distinct_country)
# Out:
# The count of number of Distinct Countries are: -
# 125

# %%
cleaned_csv_file[cleaned_csv_file['Country Name']== 'China']
# Out:
#       Country Name Country Code  \
# 24           China          CHN
# 149          China          CHN
# 274          China          CHN
# 399          China          CHN
# 524          China          CHN
# ...            ...          ...
# 49399        China          CHN
# 49524        China          CHN
# 49649        China          CHN
# 49774        China          CHN
# 49899        China          CHN
#
#                                           Indicator Name     Series Code  \
# 24     Average grace period on new external debt comm...     DT.GPA.DPPG
# 149    Average grace period on new external debt comm...     DT.GPA.OFFT
# 274    Average grace period on new external debt comm...     DT.GPA.PRVT
# 399    Average grant element on new external debt com...     DT.GRE.DPPG
# 524    Average grant element on new external debt com...     DT.GRE.OFFT
# ...                                                  ...             ...
# ...

# %%
print("The number of Distinct Countries are: -")
pd.DataFrame(cleaned_csv_file['Country Name'].unique())
# Out:
# The number of Distinct Countries are: -
#                  0
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3           Angola
# 4        Argentina
# ..             ...
# 120  Venezuela, RB
# 121        Vietnam
# 122    Yemen, Rep.
# 123         Zambia
# 124       Zimbabwe
#
# [125 rows x 1 columns]

# %% [markdown]
# #### *Finding out the distinct debt indicators*

# %%
print("The number of Distinct Countries are: -")
pd.DataFrame(cleaned_csv_file['Series Code'].unique())
# Out:
# The number of Distinct Countries are: -
#                   0
# 0       DT.GPA.DPPG
# 1       DT.GPA.OFFT
# 2       DT.GPA.PRVT
# 3       DT.GRE.DPPG
# 4       DT.GRE.OFFT
# ..              ...
# 395  DT.AMT.PROP.CD
# 396  DT.DIS.PROP.CD
# 397  DT.DOD.PROP.CD
# 398  DT.INT.PROP.CD
# 399  DT.NFL.PROP.CD
#
# [400 rows x 1 columns]

# %% [markdown]
# #### *Totalling the amount of debt owed by the countries*

# %%
cleaned_csv_file.groupby('Country Name')['debt'].sum().reset_index()
# Out:
#       Country Name               debt
# 0      Afghanistan   777678096862.173
# 1          Albania  1855169814342.250
# 2          Algeria 16272203060332.326
# 3           Angola 13975414863614.918
# 4        Argentina 65242199543882.516
# ..             ...                ...
# 120  Venezuela, RB 37003485916120.602
# 121        Vietnam 24923918553291.105
# 122    Yemen, Rep.  3841173674265.269
# 123         Zambia  4839960042308.271
# 124       Zimbabwe  2928537539189.620
#
# [125 rows x 2 columns]

# %% [markdown]
# #### *Country with the highest debt*

# %%
cleaned_csv_file.groupby('Country Name')['debt'].sum().sort_values(ascending=False).head(1)
# Out:
# Country Name
# China   377762854199707.438
# Name: debt, dtype: float64

# %% [markdown]
# #### *Average amount of debt across indicators*

# %%
cleaned_csv_file.groupby('Country Name')['debt'].agg(np.average).reset_index()
# Out:
#       Country Name             debt
# 0      Afghanistan   1944195242.155
# 1          Albania   4637924535.856
# 2          Algeria  40680507650.831
# 3           Angola  34938537159.037
# 4        Argentina 163105498859.706
# ..             ...              ...
# 120  Venezuela, RB  92508714790.302
# 121        Vietnam  62309796383.228
# 122    Yemen, Rep.   9602934185.663
# 123         Zambia  12099900105.771
# 124       Zimbabwe   7321343847.974
#
# [125 rows x 2 columns]

# %% [markdown]
# #### *The highest amount of principal repayments*

# %%
dept_indicator_name=merge_file.groupby(['Series Code','Indicator Name'])['debt'].sum().reset_index() 
dept_indicator_name.iloc[np.where(dept_indicator_name['Indicator Name'].str.contains('repayments'))].sort_values(by='debt',ascending=False)
# Out:
#        Series Code                                     Indicator Name  \
# 25  DT.AMT.DLXF.CD  Principal repayments on external debt, long-te...
# 24  DT.AMT.DLTF.CD  Principal repayments on external debt, long-te...
# 27  DT.AMT.DPNG.CD  Principal repayments on external debt, private...
# 28  DT.AMT.DPPG.CD  Principal repayments on external debt, public ...
# 22  DT.AMT.DEPS.CD  Principal repayments on external debt, public ...
# 21  DT.AMT.DEGG.CD  Principal repayments on external debt, general...
# 26  DT.AMT.DOPS.CD  Principal repayments on external debt, other p...
# 69  DT.AMT.PRPG.CD  Principal repayments on external debt, private...
#
#                  debt
# 25 77206525290713.297
# 24 58916360015712.102
# 27 44861849524029.500
# 28 32344673671729.500
# 22 23335968486305.199
# 21 19928571135460.801
# 26 11719152297510.299
# 69   163958823485.600

# %% [markdown]
# #### *The most common debt indicator*

# %%
cleaned_csv_file['Series Code'].value_counts()
# Out:
# DT.GPA.DPPG           125
# DT.NTR.BLAT.OPS.CD    125
# DT.DIS.PBND.OPS.CD    125
# DT.AMT.PBND.OPS.CD    125
# DT.TDS.BLTC.OPS.CD    125
#                      ...
# DT.DOD.DPPG.CD        125
# DT.DOD.DPNG.CD        125
# DT.DOD.PRPG.CD        125
# DT.DOD.DOPS.CD        125
# DT.NFL.PROP.CD        125
# Name: Series Code, Length: 400, dtype: int64

# %% [markdown]
# #### *Other viable debt issues and conclusion*

# %%
cleaned_csv_file.groupby('Country Name')['debt'].max().sort_values(ascending=False).reset_index().head(10)
# Out:
#          Country Name                debt
# 0               China 155933632932082.000
# 1              Brazil  42131239879449.000
# 2               India  39274423390206.000
# 3  Russian Federation  31268359000000.000
# 4              Mexico  27959914195572.000
# 5            IDA only  19314486000000.000
# 6              Turkey  16663907174315.000
# 7           Indonesia  15682041786216.000
# 8           Argentina  11627797724559.000
# 9  Iran, Islamic Rep.   9652376367749.000
